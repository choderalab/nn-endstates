# %% [markdown]
# ## Annealed Importance Sampling to exchange intramolecular talks between torchANI and openmm.

# %%
import torchani
import torch
import numpy as np
import mdtraj as md
from simtk import unit
from openmmtools.constants import kB
import random
import os

atomic_num_to_symbol_dict = {1: 'H', 6: 'C', 7: 'N', 8: 'O'}
mass_dict_in_daltons = {'H': 1.0, 'C': 12.0, 'N': 14.0, 'O': 16.0}
import numpy as np
from numba import jit
from simtk.unit.quantity import is_dimensionless
import mdtraj.utils as mdtrajutils
from openmmtools.states import ThermodynamicState, SamplerState


from perses.dispersed.utils import configure_platform
from openmmtools import cache, utils
cache.global_context_cache.platform = configure_platform(utils.get_fastest_platform().getName())

import logging
logging.basicConfig(level=logging.NOTSET)
_logger = logging.getLogger("interpolANI")
_logger.setLevel(logging.DEBUG)
# Out:
# conducting subsequent work with the following platform: CPU
# conducting subsequent work with the following platform: CPU

# %%
class ANI1_force_and_energy(object):
    
    #some imports
#     import torchani
#     import torch
#     import numpy as np
#     import mdtraj as md
#     from simtk import unit
#     from openmmtools.constants import kB
#     import random
    
    #some class attributes
    mass_unit = unit.dalton
    distance_unit = unit.nanometers
    time_unit = unit.femtoseconds
    energy_unit = unit.kilojoules_per_mole
    ani_distance_unit = unit.angstroms
    hartree_to_kJ_per_mole = 2625.499638
    ani_energy_unit = hartree_to_kJ_per_mole * energy_unit
    nm_to_angstroms = 10.
    angstroms_to_nm = 1e-1

    def __init__(self,
                 model,
                 atoms,
                 platform = 'cpu',
                 temperature = 300 * unit.kelvin
                 ):
        
        """
        Performs energy and force calculations.
        Slightly modified code from: 
            https://gist.github.com/wiederm/7ac5c29e5a0dea9d17ef16dda93fe02d#file-reweighting-py-L42; thanks, Marcus
        
        Parameters
        ----------
        model: torchani.models object
            model from which to compute energies and forces
        atoms: str
            a string of atoms in the indexed order
        platform : str, default 'cpu',
            platform on which to initialize the model device
        temperature : float * unit.kelvin, default 300 * unit.kelvin
            temperature
        """
        self.model = model
        self.atoms = atoms
        
        self.platform = platform
        self.device = torch.device(self.platform)
        if self.platform == 'cpu':
            torch.set_num_threads(2)
        else:
            raise Exception(f"we don't support gpu just yet")
        
        self.species = self.model.species_to_tensor(atoms).to(self.device).unsqueeze(0)
        self.temperature = temperature
        self.beta = 1.0/(kB*temperature)
        
        self.W_shads = []
        self.W = []


    def minimize(self, 
                 coords: unit.quantity.Quantity, 
                 maxiter: int = 1000,
                 show_plot: bool = False):
        """
        Minimizes the molecule. Note, we usually don't want to do this given an input structure since they are already distributed i.i.d.
        
        Parameters
        ----------
        coords:simtk.unit.quantity.Quantity
        maxiter: int
            Maximum number of minimization steps performed.
        lambda_value: float
            indicate position in lambda protocoll to control how dummy atoms are handled
            
        Returns
        -------
        coords:simtk.unit.quantity.Quantity
        """
        from scipy import optimize
        assert(type(coords) == unit.quantity.Quantity)


        x = coords.value_in_unit(unit.angstrom)
        self.memory_of_energy = []
        print("Begin minimizing...")
        f = optimize.minimize(self._traget_energy_function, x, method='BFGS',
                              jac=True, options={'maxiter': maxiter, 'disp': True})

        logger.critical(f"Minimization status: {f.success}")
        memory_of_energy = copy.deepcopy(self.memory_of_energy)
        self.memory_of_energy = []

        return f.x.reshape(-1, 3) * unit.angstrom, memory_of_energy

    def calculate_force(self, 
                        x: unit.quantity.Quantity) -> (unit.quantity.Quantity, unit.quantity.Quantity):
        """
        Given a coordinate set the forces with respect to the coordinates are calculated.
        
        Parameters
        ----------
        x : array of floats, unit'd (distance unit)
            initial configuration
            
        Returns
        -------
        F : float, unit'd
        E : float, unit'd
        """
        assert(type(x) == unit.quantity.Quantity)

        coordinates = torch.tensor([x.value_in_unit(unit.angstroms)],
                                   requires_grad=True, device=self.device, dtype=torch.float32)

        energy_in_hartree = self._calculate_energy(coordinates)

        # derivative of E (in kJ/mol) w.r.t. coordinates (in nm)
        derivative = torch.autograd.grad((energy_in_hartree).sum(), coordinates)[0]

        if self.platform == 'cpu':
            F = -1 * derivative[0].numpy()
        elif self.platform == 'cuda':
            F = - np.array(derivative.cpu())[0]
        else:
            raise RuntimeError('Platform needs to be specified. Either CPU or CUDA.')

        return (F * self.hartree_to_kJ_per_mole * self.nm_to_angstroms * (unit.kilojoule_per_mole / unit.nanometer),
                energy_in_hartree.item() * self.hartree_to_kJ_per_mole * unit.kilojoule_per_mole)

    def _calculate_energy(self, coordinates: torch.tensor):
        """
        Helpter function to return energies as tensor.
        Given a coordinate set the energy is calculated.
        
        Parameters
        ----------
        coordinates : torch.tensor 
            coordinates in angstroms without units attached
            
        Returns
        -------
        energy_in_hartree : torch.tensor
            
        """

        #stddev_in_hartree = torch.tensor(0.0,device = self.device, dtype=torch.float64)
        energy_in_hartree = self.model((self.species, coordinates)).energies

        return energy_in_hartree


    def _traget_energy_function(self, x) -> float:
        """
        Given a coordinate set (x) the energy is calculated in kJ/mol.
        
        Parameters
        ----------
        x : array of floats, unit'd (distance unit)
            initial configuration
            
        Returns
        -------
        E : float, unit'd 
        """
        x = x.reshape(-1, 3) * unit.angstrom
        F, E = self.calculate_force(x)
        F_flat = -np.array(F.value_in_unit(unit.kilojoule_per_mole/unit.angstrom).flatten(), dtype=np.float64)
        self.memory_of_energy.append(E)
        return E.value_in_unit(unit.kilojoule_per_mole), F_flat

    def calculate_energy(self, x: unit.Quantity):
        """
        Given a coordinate set (x) the energy is calculated in kJ/mol.
        Parameters
        ----------
        x : array of floats, unit'd (angstroms)
            initial configuration
            
        Returns
        -------
        energy : unit.quantity.Quantity
            energy in kJ/mol
        """

        assert(type(x) == unit.quantity.Quantity)
        coordinates = torch.tensor([x.value_in_unit(unit.angstroms)],
                           requires_grad=True, device=self.device, dtype=torch.float32)

        energy_in_hartrees = self._calculate_energy(coordinates)
        energy = energy_in_hartrees.item() * self.hartree_to_kJ_per_mole * unit.kilojoule_per_mole
        return energy

# %%
class InterpolAIS(object):
    """
    Class to build hybrid OpenMM/TorchANI system and conduct Annealed Importance Sampling (AIS) between the full-openMM system and the hybrid OpenMM/TorchAni system that respects the following rules:
        1.  all intermolecular talks happen with sterics
        2.  all intramolecular talks of the `ligand` of interest happen with OpenMM at lambda = 0 and with torchANI at lambda = 1
        3.  all environment atoms talk to each other with OpenMM for all lambdas
        
    Example:
    
        input : complex_system, complex_topology
        output : trajectory, particle_works
    
        
    
    """
    def __init__(self, 
                 complex_system, 
                 complex_topology,
                 ligand_system, #note this must be unique
                 ligand_subset_indices,
                 temperature = 300 * unit.kelvin,
                 pressure = 1 * unit.atmosphere,
                 trajectory_directory = 'test',
                 trajectory_prefix = 'trial_1',
                 atom_selection_string = 'not water',
                 lambda_sequence = np.array([0,1]),
                 ani_model = torchani.models.ANI1ccx(),
                 platform = 'cpu'):
        """
        create vacuum_openmm_ligand system, vacuum_torchani_ligand system, and logger object
        
        Arguments:
            complex_system : openmm.System 
                openmm system of the complex
            complex_topology : openmm.Topology
                topology of the complex
            ligand_system : openmm.System
                parametrized ligand in vacuum
            ligand_subset_indices : list of int
                complex topology ligand atom indices
            temperature : unit.quantity.Quantity, (units compatible with unit.kelvin)
                temperature
            pressure : unit.quantity.Quantity, (units compatible with unit.atmosphere)
                pressure
            trajectory_directory : str
                path of written trajectory
            trajectory_prefix : str
                name of traj prefix
            atom_selection_string : str, default 'not water'
                atom indices to save (mdtraj str)
            lambda_sequence : np.array, default np.array([0,1])
                sequence of lamda values
            ani_model: torchani.models object
                model from which to compute energies and forces
            platform : str, default 'cpu'
                which platform to use for ani
            
        """
        import numpy as np
        import os
        import simtk.openmm as openmm
        
        self.context_cache = cache.global_context_cache

        self.lambda_sequence = lambda_sequence
        
        self.complex_system = complex_system
        self.complex_topology = complex_topology
        
        self.ligand_system = ligand_system
        assert ligand_subset_indices == range(min(ligand_subset_indices), max(ligand_subset_indices)+1), f"ligand subset indices ({ligand_subset_indices}) is not a sequence"
        self.ligand_subset_indices = ligand_subset_indices
        
        #pull masses
        _logger.debug(f"defining a mass matrix")
        assert len(ligand_subset_indices) == self.ligand_system.getNumParticles(), f"the number of ligand subset indices is _not_ equal to the number of ligand system particles ({self.ligand_system.getNumParticles()})"
        for index, lig_subset_index in enumerate(ligand_subset_indices):
            assert self.complex_system.getParticleMass(lig_subset_index) == self.ligand_system.getParticleMass(index), f"masses do not match"
        self.mass_matrix = np.array([[self.complex_system.getParticleMass(q).value_in_unit(unit.daltons) for q in range(self.complex_system.getNumParticles())]]) * unit.daltons
        
        #create a thermodynamic and sampler state
        _logger.debug(f"defining thermostates")
        self.temperature = temperature
        self.pressure = pressure
        self.complex_thermostate = ThermodynamicState(system = self.complex_system, temperature = temperature, pressure = pressure)
        self.ligand_thermostate = ThermodynamicState(system = self.ligand_system, temperature = temperature)
        
#         self.complex_sampler_state = SamplerState(positions = complex_positions, box_vectors = self.complex_system.getDefaultPeriodicBoxVectors())
#         ligand_positions = unit.Quantity(np.zeros([len(self.ligand_subset_indices), 3]), unit=unit.nanometer)
#         for idx in ligand_subset:
#             ligand_positions[idx, :] = self.complex_sampler_state.positions[idx,:]
        
#         self.ligand_sampler_state = SamplerState(positions = ligand_positions, box_vectors = self.ligand_system.getDefaultPeriodicBoxVectors())
        
        
        # trajectory maker
        self.trajectory_directory, self.trajectory_prefix = trajectory_directory, trajectory_prefix
        if self.trajectory_directory is not None and self.trajectory_prefix is not None:
            _logger.debug(f"creating trajectory storage object")
            self.write_traj = True
            self.neq_traj_filename = os.path.join(os.getcwd(), self.trajectory_directory, f"{self.trajectory_prefix}.neq")
            os.mkdir(os.path.join(os.getcwd(), self.trajectory_directory))
            complex_md_topology = md.Topology().from_openmm(self.complex_topology)
            ligand_md_topology = complex_md_topology.subset(self.ligand_subset_indices)
            atom_selection_indices = complex_md_topology.select(atom_selection_string)
            self.atom_selection_indices = atom_selection_indices
            self.complex_md_topology = complex_md_topology.subset(self.atom_selection_indices)
            self.ligand_md_topology = ligand_md_topology
            
        else:
            _logger.debug(f"omitting trajectory storage object")
            self.write_traj = False
            self.neq_traj_filename = None
            self.atom_selection_indices = None
            self.complex_md_topology, self.ligand_md_topology = None, None
        
        #make the ani model
        _logger.debug(f"creating ANI handler")
        species_str = ''.join([atom.element.symbol for atom in self.complex_topology.atoms() if atom.index in self.ligand_subset_indices])
        self.ani_handler = ANI1_force_and_energy(model = ani_model,
                                                 atoms = species_str,
                                                 platform = 'cpu',
                                                 temperature = self.temperature)
        
        #make the openmm model
        self.integrator = openmm.VerletIntegrator(1.0*unit.femtosecond)
        
        #recorders
        _logger.debug(f"handling recorder objects")
        self.incremental_works = []
        self.shadow_works = []
        self.anneal_num = 0
    
    def _compute_hybrid_potential(self, 
                                  lambda_index):
        """
        function to compute the hybrid reduced potential defined as follows:
        U(x_rec, x_lig) = u_mm,rec(x_rec) - lambda*u_mm,lig(x_lig) + lambda*u_ani,lig(x_lig)
        """
        ligand_state = self.ligand_context.getState(getPositions=True)
        ligand_coords = ligand_state.getPositions(asNumpy=True)
        reduced_potential = (self.complex_thermostate.reduced_potential(self.complex_context)
                     - self.lambda_sequence[lambda_index] * self.ligand_thermostate.reduced_potential(self.ligand_context)
                     + self.lambda_sequence[lambda_index] * self.ani_handler.calculate_energy(ligand_coords) * self.complex_thermostate.beta)
        return reduced_potential
    
    def minimize(self, complex_positions):
        from perses.dispersed.utils import minimize
        complex_sampler_state, ligand_sampler_state = self._create_sampler_states(complex_positions)
        minimize(self.complex_thermostate, complex_sampler_state)
        return complex_sampler_state.positions
        
        
        
    def _compute_hybrid_forces(self,
                               lambda_index):
        """
        function to compute a hybrid force matrix of shape num_particles x 3
        in the spirit of the _compute_hybrid_potential, we compute the forces in the following way
            F(x_rec, x_lig) = F_mm(x_rec, x_lig) - lambda * F_mm(x_lig) + lambda * F_ani(x_lig)
        """
        #get the complex mm forces
        complex_state = self.complex_context.getState(getForces=True)
        complex_mm_force_matrix = complex_state.getForces(asNumpy=True)
        
        #get the ligand mm forces
        ligand_state = self.ligand_context.getState(getForces=True)
        ligand_mm_force_matrix = ligand_state.getForces(asNumpy=True)
        
        #get the ligand ani forces
        ligand_state = self.ligand_context.getState(getPositions=True)
        coords = ligand_state.getPositions(asNumpy=True)
        ligand_ani_force_matrix, energie = self.ani_handler.calculate_force(coords)
        
        #now combine the ligand forces
        ligand_force_matrix = self.lambda_sequence[lambda_index] * (ligand_ani_force_matrix - ligand_mm_force_matrix)
        
        #and append to the complex forces...
        complex_mm_force_matrix[self.ligand_subset_indices, :] += ligand_force_matrix
        
        complex_force_matrix = complex_mm_force_matrix
        return complex_force_matrix
    
    def _create_sampler_states(self, complex_positions):
        """
        simple utility function to generate complex and ligand sampler states
        """
        from openmmtools.states import SamplerState
        complex_sampler_state = SamplerState(positions = complex_positions, box_vectors = self.complex_system.getDefaultPeriodicBoxVectors())
        ligand_positions = unit.Quantity(np.zeros([len(self.ligand_subset_indices), 3]), unit=unit.nanometer)
        ligand_positions[self.ligand_subset_indices, :] = complex_sampler_state.positions[self.ligand_subset_indices,:]
        ligand_sampler_state = SamplerState(positions = ligand_positions, box_vectors = self.ligand_system.getDefaultPeriodicBoxVectors())
        
        return complex_sampler_state, ligand_sampler_state
    
    def simulate_baoab(self, 
                       _lambda_index,
                       n_steps = 1,
                       gamma = 1./unit.picoseconds, 
                       dt = 1.0 * unit.femtoseconds,
                       metropolize = False):
        """
        Simulate n_steps of BAOAB, accumulating heat
        
        args
            n_steps : int, default 1
                number of steps of dynamics to run
            gamma : unit.quantity.Quantity (units compatible with 1.0/unit.picoseconds)
                collision rate
            dt : unit.quantity.Quantity (units compatible with units.femtoseconds)
                timestep
        """
        Q = 0
        W_shads = 0.
        _complex_sampler_state, _ligand_sampler_state = SamplerState.from_context(self.complex_context), SamplerState.from_context(self.ligand_context)
        x_unit, v_unit, t_unit, m_unit = unit.nanometers, unit.nanometers/unit.femtoseconds, unit.femtoseconds, unit.daltons
        x, v = _complex_sampler_state.positions.value_in_unit(unit.nanometers), _complex_sampler_state.velocities.value_in_unit(unit.nanometers/unit.femtoseconds)
        dt = dt.value_in_unit(t_unit)
        gamma = gamma * t_unit
        mass_matrix = self.mass_matrix.value_in_unit(m_unit)
        
        def compute_kinetic_energy(v):
            return  0.5 * np.sum(np.matmul(np.square(v.T), mass_matrix.T)) * m_unit * v_unit**2 * self.complex_thermostate.beta
        
        def sample_maxwell_boltzmann():
            return np.sqrt((1./self.complex_thermostate.beta).value_in_unit(m_unit * v_unit**2)) * (np.random.randn(mass_matrix.shape[1], 3) / np.sqrt(mass_matrix)[0,:][:,None])
        
        def V(v):
            force = self._compute_hybrid_forces(_lambda_index).value_in_unit(m_unit * x_unit / (t_unit**2))
            dv = (dt / 2.) * (force / mass_matrix[0,:][:,None])
            return v + dv
        
        def R(x, v):
            dx = (dt / 2.0 ) * v
            return x + dx
        
        def OU(v):
            mb_sample = sample_maxwell_boltzmann()
            _logger.debug(f"\t\t\t\tmaxwell boltzmann sample KE: {compute_kinetic_energy(mb_sample)}")
            return a * v + b * mb_sample
            
        if metropolize:
            v = sample_maxwell_boltzmann()
        old_potential, old_ke = self._compute_hybrid_potential(_lambda_index), compute_kinetic_energy(v)
        #0.5 * np.sum(np.matmul(mass_matrix, np.square(v))) * m_unit * v_unit**2 * self.complex_thermostate.beta
        E_old = old_potential + old_ke
        x_old, v_old = x, v
        _logger.debug(f"\t\t\tbefore propagation u, ke, E_tot: {old_potential}, {old_ke},  {old_potential + old_ke}")

        # Mixing parameters for half O step
        a = np.exp(-gamma * dt)
        b = np.sqrt(1 - np.exp(-2 * gamma * dt))
        _logger.debug(f"\t\t\ta, b scales: {a}, {b}")

        _logger.debug(f"\t\t\tbeginning integration...")
        for i in range(n_steps):
            #####################################
            #####################################

            # V step
            v = V(v)
            _logger.debug(f"\t\t\t\tV")
            _logger.debug(f"\t\t\t\t\tupdated ke: {compute_kinetic_energy(v)}")

            # R step
            x = R(x,v)
            _logger.debug(f"\t\t\t\tR")

            # O step
            _logger.debug(f"\t\t\t\tO")
            ke_old = compute_kinetic_energy(v)
            _logger.debug(f"\t\t\t\tke_old: {ke_old}")
            
            v = OU(v)

            ke_new = compute_kinetic_energy(v)
            _logger.debug(f"\t\t\t\tke_new: {ke_new}") 
            
            Q += (ke_new - ke_old)
            _logger.debug(f"\t\t\t\t heat change: {Q}")

            # R step
            x = R(x,v)
            _logger.debug(f"\t\t\t\tR")

            #update contexts before computing forces again
            _complex_sampler_state.positions = x * x_unit
            _complex_sampler_state.velocities = v * v_unit
            _complex_sampler_state.apply_to_context(self.complex_context)
            _ligand_sampler_state.positions = x[self.ligand_subset_indices,:] * x_unit
            _ligand_sampler_state.apply_to_context(self.ligand_context)

            # V step
            v = V(v)
            _logger.debug(f"\t\t\t\tV")
            _logger.debug(f"\t\t\t\t\tupdated ke: {compute_kinetic_energy(v)}")

            # Update W_shads
            new_potential, new_ke = self._compute_hybrid_potential(_lambda_index), compute_kinetic_energy(v)
            E_new = new_potential + new_ke
            W_shads += (E_new - E_old - Q)

            #####################################
            #####################################
        
        #update_contexts
        _logger.debug(f"\t\t\tafter propagation u, ke, E_new: {new_potential}, {new_ke}, {new_potential + new_ke}")
        acceptance_probability = min(1., np.exp(E_old - E_new))
        _logger.debug(f"\t\t\tacceptance_probability: {acceptance_probability}")
        if (metropolize and acceptance_probability >= np.random.rand()) or (not metropolize):
            _logger.debug(f"\t\t\taccepted")
            _complex_sampler_state.velocities = v * v_unit
            _complex_sampler_state.apply_to_context(self.complex_context)
        else:
            _logger.debug(f"\t\t\trejected")
            _complex_sampler_state.positions = x_old * x_unit
            _complex_sampler_state.velocities = v_old * v_unit
            _ligand_sampler_state.positions = x_old[self.ligand_subset_indices,:] * x_unit
            _complex_sampler_state.apply_to_context(self.complex_context)
            _ligand_sampler_state.apply_to_context(self.ligand_context)
            Q, W_shads = 0., 0.
        _logger.debug(f"\t\tshadow_work: {W_shads}")
        
        return Q, W_shads
    
    def _record_trajectory(self, complex_sampler_state):
        """
        wrapper to record sampler state
        """
        if self.write_traj:
            self.trajectory_positions.append(complex_sampler_state.positions[self.atom_selection_indices, :].value_in_unit_system(unit.md_unit_system))
            a, b, c, alpha, beta, gamma = mdtrajutils.unitcell.box_vectors_to_lengths_and_angles(*complex_sampler_state.box_vectors)
            self.box_lengths.append([a,b,c])
            self.box_angles.append([alpha, beta, gamma])
        
    def anneal(self, 
               complex_positions, 
               n_steps_per_propagation = 1, 
               gamma = 1./unit.picoseconds, 
               dt = 0.5 * unit.femtoseconds,
               metropolize_propagator = False):
        
        _logger.debug(f"conducting annealing...")
        import copy
        #first make contexts and sampler states
        _logger.debug(f"creating contexts and sampler states...")
        complex_sampler_state, ligand_sampler_state = self._create_sampler_states(complex_positions)
        self.complex_context, complex_integrator = self.context_cache.get_context(self.complex_thermostate, copy.deepcopy(self.integrator))
        self.ligand_context, ligand_integrator = self.context_cache.get_context(self.ligand_thermostate, copy.deepcopy(self.integrator))
        complex_sampler_state.apply_to_context(self.complex_context)
        self.complex_context.setVelocitiesToTemperature(self.complex_thermostate.temperature)
        complex_sampler_state.update_from_context(self.complex_context)
        
        ligand_sampler_state.apply_to_context(self.ligand_context)
        
        #then we have to make some recording objects
        incremental_works = [0.]
        shadow_works = [0.]
        self.trajectory_positions = []
        self.box_lengths, self.box_angles = [], []
        self._record_trajectory(complex_sampler_state)
        
        reduced_potential = self._compute_hybrid_potential(
                                                      lambda_index = 0)
        _logger.debug(f"initial hybrid reduced potential: {reduced_potential}")
        
        _logger.debug(f"conducting annealing protocol for lambda sequence...")
        for _lambda_index in range(1,len(self.lambda_sequence)):
            _logger.debug(f"\tlambda value: {self.lambda_sequence[_lambda_index]}")
            
            #first thing to do is update the reduced potential
            new_reduced_potential = self._compute_hybrid_potential(
                                                      lambda_index = _lambda_index)
            _logger.debug(f"\t\tnew reduced potential: {new_reduced_potential}")
            
            incremental_work = new_reduced_potential - reduced_potential
            _logger.debug(f"\t\tincremental_work: {incremental_work}")
            incremental_works.append(new_reduced_potential - reduced_potential)
            
            #now we can propagate
            _logger.debug(f"\t\tcomplex_positions_sample: {complex_sampler_state.positions[0,:]}")
            _logger.debug(f"\t\tcomplex_velocities_sample: {complex_sampler_state.velocities[0,:]}")
            _logger.debug(f"\t\tpropagating particle {n_steps_per_propagation} steps...")
            try:
                Q, schatten = self.simulate_baoab( 
                                                        _lambda_index,
                                                        n_steps_per_propagation,
                                                        gamma, 
                                                        dt,
                                                        metropolize_propagator)

            

                shadow_works.append(schatten)
                ligand_sampler_state.update_from_context(self.ligand_context)
                complex_sampler_state.update_from_context(self.complex_context)
                _logger.debug(f"\t\tcomplex_positions_sample updated: {complex_sampler_state.positions[0,:]}")
                _logger.debug(f"\t\tcomplex_velocities_sample updated: {complex_sampler_state.velocities[0,:]}")

                self._record_trajectory(complex_sampler_state)

                reduced_potential =  self._compute_hybrid_potential(
                                                                      lambda_index = _lambda_index)
            
            except Exception as e:
                _logger.warning(f"{e}")
                break
        
        #now that we are out of the loop, we can write to the recorders
        self.incremental_works.append(incremental_works)
        self.shadow_works.append(shadow_works)
        if self.write_traj:
            try:
                trajectory = md.Trajectory(np.array(self.trajectory_positions), self.complex_md_topology, unitcell_lengths=np.array(self.box_lengths), unitcell_angles=np.array(self.box_angles))
                trajectory.center_coordinates()
                trajectory.save(f"{self.neq_traj_filename}.{self.anneal_num}.pdb")
            except Exception as e:
                _logger.warning(f"{e}")
                _shape = np.array(self.trajectory_positions).shape
                self.trajectory_positions = np.array(self.trajectory_positions)
                to_val = int(np.floor(0.9 * _shape[0]))
                trajectory = md.Trajectory(np.array(self.trajectory_positions[:to_val,:]), self.complex_md_topology, unitcell_lengths=np.array(self.box_lengths)[:to_val,:], unitcell_angles=np.array(self.box_angles)[:to_val,:])
                trajectory.center_coordinates()
                trajectory.save(f"{self.neq_traj_filename}.{self.anneal_num}.pdb")
        _logger.debug(f"incremental works: {incremental_works}")
            
        self.anneal_num += 1

# %%
def build_solvated_model(smiles):
    from perses.utils.openeye import smiles_to_oemol
    import openeye.oechem as oechem
    from openmoltools.forcefield_generators import generateOEMolFromTopologyResidue, generateTopologyFromOEMol
    from openmmforcefields.generators import SystemGenerator
    import simtk.openmm.app as app
    from openforcefield.topology import Molecule
    import simtk.openmm as openmm
    
    forcefield_files = ['amber14/protein.ff14SB.xml', 'amber14/tip3p.xml']
    oemol = smiles_to_oemol(smi)
    molecules = [Molecule.from_openeye(oemol)]
    
    coords = oemol.GetCoords()
    vac_pos = np.array([list(coords[i]) for i, j in coords.items()]) * unit.angstroms
    vac_top = generateTopologyFromOEMol(oemol)
    
    vac_barostat = None
    vac_system_generator = SystemGenerator(forcefield_files,
                                   barostat = vac_barostat,
                                   forcefield_kwargs = {'removeCMMotion': False, 
                                                        'ewaldErrorTolerance': 1e-4, 
                                                        'nonbondedMethod': app.NoCutoff,
                                                        'constraints' : None, 
                                                        'hydrogenMass' : 4 * unit.amus},
                                   small_molecule_forcefield = 'gaff-2.11',
                                   molecules = molecules, cache = None
                                   )
    
    solv_barostat = openmm.MonteCarloBarostat(1.0 * unit.atmosphere, 300 * unit.kelvin, 50)
    solv_system_generator = SystemGenerator(forcefield_files,
                                   barostat = solv_barostat,
                                   forcefield_kwargs = {'removeCMMotion': False, 
                                                        'ewaldErrorTolerance': 1e-4, 
                                                        'nonbondedMethod': app.PME,
                                                        'constraints' : None, 
                                                        'rigidWater': False,
                                                        'hydrogenMass' : 4 * unit.amus},
                                   small_molecule_forcefield = 'gaff-2.11',
                                   molecules = molecules, cache = None
                                   )
    
    
    modeller = app.Modeller(vac_top, vac_pos)
    modeller.addSolvent(solv_system_generator.forcefield, model='tip3p', padding=9*unit.angstroms, ionicStrength=0.15*unit.molar)
    solvated_topology = modeller.getTopology()
    solvated_positions = modeller.getPositions()

    # canonicalize the solvated positions: turn tuples into np.array
    solvated_positions = unit.quantity.Quantity(value = np.array([list(atom_pos) for atom_pos in solvated_positions.value_in_unit_system(unit.md_unit_system)]), unit = unit.nanometers)
    solvated_topology = solvated_topology
    solvated_system = solv_system_generator.create_system(solvated_topology)
    
    vacuum_positions = unit.quantity.Quantity(value = np.array([list(atom_pos) for atom_pos in vac_pos.value_in_unit_system(unit.md_unit_system)]), unit = unit.nanometers)
    vacuum_topology = vac_top
    vacuum_system = vac_system_generator.create_system(vacuum_topology)
    
    return vacuum_system, vacuum_positions, vacuum_topology, solvated_system, solvated_positions, solvated_topology

# %%
smi = 'CCC'
vac_sys, vac_pos, vac_top, solv_sys, solv_pos, solv_top = build_solvated_model(smi)
# Out:
# INFO:utils.openeye:molecule                       does not have unique atom names. Generating now...
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11
# INFO:openmmforcefields.generators.template_generators:Requested to generate parameters for residue <Residue 0 (MOL) of chain 0>
# INFO:openmmforcefields.generators.template_generators:Generating a residue template for [H]C([H])([H])C([H])([H])C([H])([H])[H]
# DEBUG:openmmforcefields.generators.template_generators:Total charge is 0
# DEBUG:openmmforcefields.generators.template_generators:Computing AM1-BCC charges...
# DEBUG:openmmforcefields.generators.template_generators:Generating a conformer...
# DEBUG:openmmforcefields.generators.template_generators:Running antechamber...
# DEBUG:openmmforcefields.generators.template_generators:antechamber -i in.mdl -fi mdl -o out.mol2 -fo mol2 -s 0 -at 2 -dr no
# DEBUG:openmmforcefields.generators.template_generators:
# Welcome to antechamber 19.0: molecular input file processor.
#
#
# DEBUG:openmmforcefields.generators.template_generators:parmchk2 -i out.mol2 -f mol2 -p /home/dominic/anaconda3/envs/openmm/lib/python3.6/site-packages/openmmforcefields/ffxml/amber/gaff/dat/gaff-2.11.dat -o out.frcmod -s %2
# DEBUG:openmmforcefields.generators.template_generators:
# DEBUG:openmmforcefields.generators.template_generators:Reading GAFF atom types...
# DEBUG:openmmforcefields.generators.template_generators:Fixing partial charges...
# DEBUG:openmmforcefields.generators.template_generators:[-0.09245001 -0.09245001 -0.08114     0.03206     0.03206     0.03206
#   0.03206     0.03206     0.03206     0.03684     0.03684   ] e
# DEBUG:openmmforcefields.generators.template_generators:[-0.09245001 -0.09245001 -0.08114     0.03206     0.03206     0.03206
#   0.03206     0.03206     0.03206     0.03684     0.03684   ] e
# DEBUG:openmmforcefields.generators.template_generators:Creating ffxml contents for additional parameters...
# DEBUG:parmed.openmm.parameters:Valid patch combinations:
# DEBUG:openmmforcefields.generators.template_generators:Creating residue template...
# DEBUG:openmmforcefields.generators.template_generators:ffxml creation complete.
# INFO:openmmforcefields.generators.template_generators:Requested to generate parameters for residue <Residue 0 (MOL) of chain 0>
# INFO:openmmforcefields.generators.template_generators:Generating a residue template for [H]C([H])([H])C([H])([H])C([H])([H])[H]
# DEBUG:openmmforcefields.generators.template_generators:Total charge is 0
# DEBUG:openmmforcefields.generators.template_generators:Computing AM1-BCC charges...
# DEBUG:openmmforcefields.generators.template_generators:Generating a conformer...
# DEBUG:openmmforcefields.generators.template_generators:Running antechamber...
# DEBUG:openmmforcefields.generators.template_generators:antechamber -i in.mdl -fi mdl -o out.mol2 -fo mol2 -s 0 -at 2 -dr no
# DEBUG:openmmforcefields.generators.template_generators:
# Welcome to antechamber 19.0: molecular input file processor.
#
#
# DEBUG:openmmforcefields.generators.template_generators:parmchk2 -i out.mol2 -f mol2 -p /home/dominic/anaconda3/envs/openmm/lib/python3.6/site-packages/openmmforcefields/ffxml/amber/gaff/dat/gaff-2.11.dat -o out.frcmod -s %2
# DEBUG:openmmforcefields.generators.template_generators:
# DEBUG:openmmforcefields.generators.template_generators:Reading GAFF atom types...
# DEBUG:openmmforcefields.generators.template_generators:Fixing partial charges...
# DEBUG:openmmforcefields.generators.template_generators:[-0.09245001 -0.09245001 -0.08114     0.03206     0.03206     0.03206
#   0.03206     0.03206     0.03206     0.03684     0.03684   ] e
# DEBUG:openmmforcefields.generators.template_generators:[-0.09245001 -0.09245001 -0.08114     0.03206     0.03206     0.03206
#   0.03206     0.03206     0.03206     0.03684     0.03684   ] e
# DEBUG:openmmforcefields.generators.template_generators:Creating ffxml contents for additional parameters...
# DEBUG:parmed.openmm.parameters:Valid patch combinations:
# DEBUG:openmmforcefields.generators.template_generators:Creating residue template...
# DEBUG:openmmforcefields.generators.template_generators:ffxml creation complete.

# %%
ress = [res for res in solv_top.residues() if res.name == 'MOL']
assert len(ress) == 1
for atom in ress[0].atoms():
    print(atom.index, atom.name)
# Out:
# 0 C1
# 1 C3
# 2 C2
# 3 H1
# 4 H2
# 5 H3
# 6 H6
# 7 H7
# 8 H8
# 9 H4
# 10 H5

# %%
os.system('rm -r test')
    
inter = InterpolAIS(complex_system = solv_sys, 
                 complex_topology = solv_top,
                 ligand_system = vac_sys, #note this must be unique
                 ligand_subset_indices = range(11),
                 temperature = 300 * unit.kelvin,
                 pressure = 1 * unit.atmosphere,
                 trajectory_directory = 'test',
                 trajectory_prefix = 'trial_1',
                 atom_selection_string = 'all',
                 lambda_sequence = np.zeros(100),
                 ani_model = torchani.models.ANI1ccx(),
                 platform = 'cpu')
# Out:
# DEBUG:interpolANI:defining a mass matrix
# DEBUG:interpolANI:defining thermostates
# DEBUG:interpolANI:creating trajectory storage object
# DEBUG:interpolANI:creating ANI handler
# DEBUG:interpolANI:handling recorder objects

# %%
print(solv_pos)
solv_pos = inter.minimize(solv_pos)
print(solv_pos)
inter.anneal(complex_positions = solv_pos, 
             n_steps_per_propagation = 1, 
             gamma = 1./unit.picoseconds, 
             dt = 1. * unit.femtoseconds,
             metropolize_propagator = False)
# Out:
# DEBUG:sMC_utils:using global context cache
# [[-0.05531941 -0.02785862  0.09028597]
#  [ 0.11306646  0.08191459  0.23888683]
#  [ 0.03848772 -0.04425296  0.20869644]
#  ...
#  [ 0.1807997   0.60733534 -0.74887565]
#  [ 1.5265997   0.29853534  0.29782435]
#  [ 0.3392997   1.51623534 -0.09997565]] nm
# DEBUG:interpolANI:conducting annealing...
# DEBUG:interpolANI:creating contexts and sampler states...
# DEBUG:interpolANI:initial hybrid reduced potential: -5939.939436514039
# DEBUG:interpolANI:conducting annealing protocol for lambda sequence...
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5939.939436514039
# DEBUG:interpolANI:		incremental_work: 0.0
# DEBUG:interpolANI:		complex_positions_sample: [-0.05639825 -0.03574888  0.09109467] nm
# DEBUG:interpolANI:		complex_velocities_sample: [-0.06093005 -0.55583403  0.19661547] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# [[-0.05639825 -0.03574888  0.09109467]
#  [ 0.12049006  0.08733309  0.23470331]
#  [ 0.04366939 -0.04674415  0.21076648]
#  ...
#  [ 0.22274554  0.63987432  1.33570869]
#  [ 1.49330592  2.06770775  0.15892769]
#  [ 0.31624601  1.49013439  2.07413025]] nm
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5939.939430396677, 1290.5603754871986,  -4649.379054909479
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 1290.187782626787
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 1290.187782626787
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1366.750048192943
# DEBUG:interpolANI:				ke_new: 1291.0514653109988
# DEBUG:interpolANI:				 heat change: 0.8636826842116534
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 1232.5586329529424
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5878.690607291404, 1232.5586329529424, -4646.131974338462
# DEBUG:interpolANI:			acceptance_probability: 0.0388875717763245
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 2.3833978868055965
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.05641597 -0.03632844  0.09132187] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.04602822 -0.52106446  0.19252414] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5878.690610350086
# DEBUG:interpolANI:		incremental_work: -1.0705382010200992e-05
# DEBUG:interpolANI:		complex_positions_sample: [-0.05641597 -0.03632844  0.09132187] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.04602822 -0.52106446  0.19252414] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5878.690604232725, 1232.5586329529424,  -4646.131971279782
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 1178.69850874115
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 1178.69850874115
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1380.947078084871
# DEBUG:interpolANI:				ke_new: 1178.039214484027
# DEBUG:interpolANI:				 heat change: -0.6592942571228377
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 1090.4465913111103
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5731.89851583946, 1090.4465913111103, -4641.45192452835
# DEBUG:interpolANI:			acceptance_probability: 0.009278580090016504
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 5.339341008555039
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.05629614 -0.03679028  0.09145769] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.20027883 -0.33963465  0.03105506] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5731.89852042748
# DEBUG:interpolANI:		incremental_work: -1.5293408068828285e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.05629614 -0.03679028  0.09145769] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.20027883 -0.33963465  0.03105506] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5731.89852042748, 1090.4465913111103,  -4641.451929116371
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 1018.0769969113759
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 1018.0769969113759
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1255.5732106328553
# DEBUG:interpolANI:				ke_new: 1018.4136970360506
# DEBUG:interpolANI:				 heat change: 0.336700124674735
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 945.2055566779665
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5581.276949817606, 945.2055566779665, -4636.071393139639
# DEBUG:interpolANI:			acceptance_probability: 0.004605352906385687
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 5.043835852056418
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.05600909 -0.03697993  0.09142778] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.36376555 -0.01614847 -0.1140692 ] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5581.276946758925
# DEBUG:interpolANI:		incremental_work: -4.588020601659082e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.05600909 -0.03697993  0.09142778] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.36376555 -0.01614847 -0.1140692 ] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5581.276946758925, 945.2055566779665,  -4636.071390080959
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 897.3373061963166
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 897.3373061963166
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1355.30888273363
# DEBUG:interpolANI:				ke_new: 895.5096989204646
# DEBUG:interpolANI:				 heat change: -1.8276072758519604
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 868.2598122738249
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5504.408758805105, 868.2598122738249, -4636.148946531281
# DEBUG:interpolANI:			acceptance_probability: 1.0
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 1.7500508255300247
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.0555976  -0.03686278  0.09123817] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.43832221  0.23084459 -0.26549665] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5504.408758805105
# DEBUG:interpolANI:		incremental_work: -9.176041203318164e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.0555976  -0.03686278  0.09123817] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.43832221  0.23084459 -0.26549665] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5504.408751158404, 868.2598122738251,  -4636.1489388845785
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 869.9231726299182
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 869.9231726299182
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1358.8428442267402
# DEBUG:interpolANI:				ke_new: 870.1546434431401
# DEBUG:interpolANI:				 heat change: 0.23147081322190388
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 890.0147693561013
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5528.37633395246, 890.0147693561013, -4638.361564596359
# DEBUG:interpolANI:			acceptance_probability: 1.0
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: -2.4440965250025783
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.0551204  -0.03646194  0.0908504 ] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.49269458  0.51489834 -0.48435954] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5528.376324776419
# DEBUG:interpolANI:		incremental_work: 7.646701305930037e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.0551204  -0.03646194  0.0908504 ] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.49269458  0.51489834 -0.48435954] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5528.37633395246, 890.0147693561013,  -4638.361564596359
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 934.0027156672575
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 934.0027156672575
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1333.331141676673
# DEBUG:interpolANI:				ke_new: 933.7590138454129
# DEBUG:interpolANI:				 heat change: -0.2437018218445246
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 973.0033701751885
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5616.553581266003, 973.0033701751885, -4643.550211090815
# DEBUG:interpolANI:			acceptance_probability: 1.0
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: -4.944944672610973
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.05460702 -0.03590193  0.09027284] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.51081836  0.53073981 -0.62360124] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5616.5535843246835
# DEBUG:interpolANI:		incremental_work: 1.223472281708382e-05
# DEBUG:interpolANI:		complex_positions_sample: [-0.05460702 -0.03590193  0.09027284] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.51081836  0.53073981 -0.62360124] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5616.553587383364, 973.0033701751885,  -4643.550217208176
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 1026.6802196092704
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 1026.6802196092704
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1308.9577219161556
# DEBUG:interpolANI:				ke_new: 1028.4100224233446
# DEBUG:interpolANI:				 heat change: 1.729802814074219
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 1048.2536481623017
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5694.257075096037, 1048.2536481623017, -4646.003426933735
# DEBUG:interpolANI:			acceptance_probability: 1.0
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: -4.183012539632955
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.05408568 -0.03539832  0.08966829] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.51214622  0.40689478 -0.53439882] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5694.257068978675
# DEBUG:interpolANI:		incremental_work: 3.058680704270955e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.05408568 -0.03539832  0.08966829] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.51214622  0.40689478 -0.53439882] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5694.257070508016, 1048.2536481623017,  -4646.003422345714
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 1074.3785617753174
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 1074.3785617753174
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1301.677078105095
# DEBUG:interpolANI:				ke_new: 1078.072557144842
# DEBUG:interpolANI:				 heat change: 3.6939953695246004
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 1054.597982293243
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5697.639723327886, 1054.597982293243, -4643.041741034643
# DEBUG:interpolANI:			acceptance_probability: 0.05173186665357644
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: -0.7323140584530847
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.05358482 -0.03505295  0.08914429] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.47858951  0.22947816 -0.46944239] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5697.639720269205
# DEBUG:interpolANI:		incremental_work: -1.2234721907589119e-05
# DEBUG:interpolANI:		complex_positions_sample: [-0.05358482 -0.03505295  0.08914429] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.47858951  0.22947816 -0.46944239] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5697.639717210524, 1054.597982293243,  -4643.041734917281
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 1036.0947313610468
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 1036.0947313610468
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1308.8745124431139
# DEBUG:interpolANI:				ke_new: 1034.2333925921075
# DEBUG:interpolANI:				 heat change: -1.8613387689392766
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 973.9768611677506
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5615.741307785942, 973.9768611677506, -4641.764446618191
# DEBUG:interpolANI:			acceptance_probability: 0.2787922776272796
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 3.138627068029564
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.05314508 -0.03491989  0.08873584] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.40509814  0.00352993 -0.31836316] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5615.741304727261
# DEBUG:interpolANI:		incremental_work: 0.0
# DEBUG:interpolANI:		complex_positions_sample: [-0.05314508 -0.03491989  0.08873584] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.40509814  0.00352993 -0.31836316] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5615.741310844622, 973.9768611677506,  -4641.764449676871
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 924.9048684269584
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 924.9048684269584
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1293.7640548158677
# DEBUG:interpolANI:				ke_new: 924.9619231024501
# DEBUG:interpolANI:				 heat change: 0.05705467549171317
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 858.7959488314549
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5495.819839963175, 858.7959488314549, -4637.02389113172
# DEBUG:interpolANI:			acceptance_probability: 0.008733766619878998
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 4.683503869658921
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.05277727 -0.03504234  0.08853025] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.35146876 -0.25387813 -0.09016677] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5495.819833845813
# DEBUG:interpolANI:		incremental_work: 0.0
# DEBUG:interpolANI:		complex_positions_sample: [-0.05277727 -0.03504234  0.08853025] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.35146876 -0.25387813 -0.09016677] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5495.819836904493, 858.7959488314549,  -4637.0238880730385
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 813.2554458184652
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 813.2554458184652
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1335.107062441049
# DEBUG:interpolANI:				ke_new: 816.54391707619
# DEBUG:interpolANI:				 heat change: 3.2884712577248365
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 779.5832629854393
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5410.165720547189, 779.5832629854393, -4630.58245756175
# DEBUG:interpolANI:			acceptance_probability: 0.0015941246354691473
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 3.1529592535638358
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.05240726 -0.03543857  0.08855787] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.4169098  -0.51156639  0.11730032] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5410.165732781912
# DEBUG:interpolANI:		incremental_work: -3.058680704270955e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.05240726 -0.03543857  0.08855787] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.4169098  -0.51156639  0.11730032] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5410.165732781912, 779.5832629854393,  -4630.582469796473
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 769.5345823780776
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 769.5345823780776
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1340.6638074627626
# DEBUG:interpolANI:				ke_new: 771.2913090728712
# DEBUG:interpolANI:				 heat change: 1.7567266947935423
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 777.8299818582346
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5407.210085118954, 777.8299818582346, -4629.38010326072
# DEBUG:interpolANI:			acceptance_probability: 0.30048226779403664
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: -0.5543601590406979
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.05198102 -0.03603143  0.08872767] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.46404978 -0.62241251  0.16999245] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5407.210079001593
# DEBUG:interpolANI:		incremental_work: 6.11736140854191e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.05198102 -0.03603143  0.08872767] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.46404978 -0.62241251  0.16999245] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5407.210085118954, 777.8299818582346,  -4629.38010326072
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 810.1297982925335
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 810.1297982925335
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1370.5653686503072
# DEBUG:interpolANI:				ke_new: 812.514155223805
# DEBUG:interpolANI:				 heat change: 2.3843569312715545
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 846.9763843067085
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5477.936966278988, 846.9763843067085, -4630.960581972279
# DEBUG:interpolANI:			acceptance_probability: 1.0
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: -3.9648356428309626
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.05144822 -0.03671977  0.08888882] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.62312326 -0.69103236  0.09080304] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5477.936950985585
# DEBUG:interpolANI:		incremental_work: 9.176042112812866e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.05144822 -0.03671977  0.08888882] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.62312326 -0.69103236  0.09080304] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5477.936947926904, 846.9763843067085,  -4630.960563620196
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 899.2674959124339
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 899.2674959124339
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1365.9838538573667
# DEBUG:interpolANI:				ke_new: 897.9959530001853
# DEBUG:interpolANI:				 heat change: -1.2715429122486057
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 924.4836043080333
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5561.475647909635, 924.4836043080333, -4636.992043601602
# DEBUG:interpolANI:			acceptance_probability: 1.0
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: -4.759937069157331
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.05076635 -0.0373941   0.08898563] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.74938868 -0.59713846  0.04092498] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5561.475638733594
# DEBUG:interpolANI:		incremental_work: 3.058680704270955e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.05076635 -0.0373941   0.08898563] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.74938868 -0.59713846  0.04092498] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5561.475647909635, 924.4836043080333,  -4636.992043601602
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 959.1923043288706
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 959.1923043288706
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1392.3204887155812
# DEBUG:interpolANI:				ke_new: 958.3059309331258
# DEBUG:interpolANI:				 heat change: -0.8863733957448403
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 944.3924575810016
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5584.744571905464, 944.3924575810016, -4640.3521143244625
# DEBUG:interpolANI:			acceptance_probability: 1.0
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: -2.473697327115815
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.04992062 -0.0379575   0.08893055] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.93441753 -0.48522415 -0.20112238] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5584.744574964145
# DEBUG:interpolANI:		incremental_work: 0.0
# DEBUG:interpolANI:		complex_positions_sample: [-0.04992062 -0.0379575   0.08893055] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.93441753 -0.48522415 -0.20112238] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5584.744574964145, 944.3924575810016,  -4640.352117383143
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 933.6567093181491
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 933.6567093181491
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1298.0765425634684
# DEBUG:interpolANI:				ke_new: 936.2995030326322
# DEBUG:interpolANI:				 heat change: 2.642793714483105
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 873.5809824064925
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5509.791870741907, 873.5809824064925, -4636.210888335414
# DEBUG:interpolANI:			acceptance_probability: 0.0159032935813
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 1.498435333246107
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.04894484 -0.0383313   0.08853876] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.99267504 -0.24247279 -0.5982764 ] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5509.791864624546
# DEBUG:interpolANI:		incremental_work: -6.11736140854191e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.04894484 -0.0383313   0.08853876] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.99267504 -0.24247279 -0.5982764 ] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5509.791867683227, 873.5809824064925,  -4636.210885276734
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 816.9507425306745
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 816.9507425306745
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1344.7244738682382
# DEBUG:interpolANI:				ke_new: 818.7464847532113
# DEBUG:interpolANI:				 heat change: 1.7957422225368873
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 729.8946567198428
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5359.674518720897, 729.8946567198428, -4629.779862001054
# DEBUG:interpolANI:			acceptance_probability: 0.0016108016966681503
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 4.635281053142876
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.0478525  -0.03848438  0.08778707] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 1.15090625 -0.07051149 -0.88103725] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5359.674521779578
# DEBUG:interpolANI:		incremental_work: -6.117360499047209e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.0478525  -0.03848438  0.08778707] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 1.15090625 -0.07051149 -0.88103725] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5359.674512603536, 729.8946567198429,  -4629.779855883693
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 656.3711901725695
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 656.3711901725695
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1331.2709869493062
# DEBUG:interpolANI:				ke_new: 657.0347892698508
# DEBUG:interpolANI:				 heat change: 0.6635990972812351
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 581.4606377465195
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5205.595094873115, 581.4606377465195, -4624.134457126595
# DEBUG:interpolANI:			acceptance_probability: 0.003533739016623331
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 4.9817996598163745
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.04670646 -0.03844703  0.0867622 ] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 1.0907589   0.11393173 -1.11425324] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5205.595094873115
# DEBUG:interpolANI:		incremental_work: -3.0586797947762534e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.04670646 -0.03844703  0.0867622 ] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 1.0907589   0.11393173 -1.11425324] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5205.595097931796, 581.4606377465196,  -4624.134460185276
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 531.1921260544467
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 531.1921260544467
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1371.033032160129
# DEBUG:interpolANI:				ke_new: 532.2942616670284
# DEBUG:interpolANI:				 heat change: 1.1021356125817192
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 503.14773336829217
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5123.872290495547, 503.14773336829217, -4620.724557127254
# DEBUG:interpolANI:			acceptance_probability: 0.0330444036104722
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 2.307767445440163
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.04567285 -0.03826658  0.08556549] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.9312209   0.19759733 -1.20474493] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5123.872293554226
# DEBUG:interpolANI:		incremental_work: -6.117360499047209e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.04567285 -0.03826658  0.08556549] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.9312209   0.19759733 -1.20474493] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5123.872293554226, 503.14773336829217,  -4620.724560185934
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 503.98315463578047
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 503.98315463578047
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1372.4300504507917
# DEBUG:interpolANI:				ke_new: 504.73085498430873
# DEBUG:interpolANI:				 heat change: 0.7477003485282694
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 528.6141197677696
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5150.323036174442, 528.6141197677696, -4621.708916406672
# DEBUG:interpolANI:			acceptance_probability: 1.0
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: -1.7320565692662058
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.04483683 -0.03806972  0.08433386] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.70896257  0.14330804 -1.17912349] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5150.323033115761
# DEBUG:interpolANI:		incremental_work: 0.0
# DEBUG:interpolANI:		complex_positions_sample: [-0.04483683 -0.03806972  0.08433386] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.70896257  0.14330804 -1.17912349] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5150.32303005708, 528.6141197677696,  -4621.708910289311
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 579.0873713051566
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 579.0873713051566
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1267.4792575526558
# DEBUG:interpolANI:				ke_new: 579.6452127056313
# DEBUG:interpolANI:				 heat change: 0.5578414004746719
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 633.0931321995425
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5258.953747350917, 633.0931321995425, -4625.860615151375
# DEBUG:interpolANI:			acceptance_probability: 1.0
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: -4.7095462625391065
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.04426654 -0.0379437   0.08317937] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.42262202  0.06686833 -1.05890137] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5258.953756526958
# DEBUG:interpolANI:		incremental_work: -1.2234721907589119e-05
# DEBUG:interpolANI:		complex_positions_sample: [-0.04426654 -0.0379437   0.08317937] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.42262202  0.06686833 -1.05890137] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5258.9537442922365, 633.0931321995425,  -4625.860612092694
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 703.8662081247622
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 703.8662081247622
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1380.9316038400284
# DEBUG:interpolANI:				ke_new: 702.9815195455884
# DEBUG:interpolANI:				 heat change: -0.8846885791738259
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 746.5784927262347
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5378.001754771835, 746.5784927262347, -4631.4232620456005
# DEBUG:interpolANI:			acceptance_probability: 1.0
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: -4.677961373732387
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.04393982 -0.03797299  0.08227308] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.24499909 -0.14553075 -0.71049946] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5378.0017517131555
# DEBUG:interpolANI:		incremental_work: 6.117360499047209e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.04393982 -0.03797299  0.08227308] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.24499909 -0.14553075 -0.71049946] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5378.001757830516, 746.5784927262347,  -4631.423265104281
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 798.1620415438433
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 798.1620415438433
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1365.345835438211
# DEBUG:interpolANI:				ke_new: 801.6751598741824
# DEBUG:interpolANI:				 heat change: 3.5131183303391254
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 805.4459951496129
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5435.314286723044, 805.4459951496129, -4629.868291573431
# DEBUG:interpolANI:			acceptance_probability: 0.21119497271830032
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: -1.9581447994886503
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.0438194  -0.03821602  0.08175017] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.03229457 -0.33521399 -0.33691197] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5435.314286723044
# DEBUG:interpolANI:		incremental_work: -3.058680704270955e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.0438194  -0.03821602  0.08175017] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.03229457 -0.33521399 -0.33691197] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5435.314286723044, 805.4459951496129,  -4629.868291573431
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 813.4225980951363
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 813.4225980951363
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1335.6157489933953
# DEBUG:interpolANI:				ke_new: 812.0722165661665
# DEBUG:interpolANI:				 heat change: -1.3503815289698196
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 772.0976942957618
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5401.375194152817, 772.0976942957618, -4629.277499857055
# DEBUG:interpolANI:			acceptance_probability: 0.5538885884300353
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 1.9411732453456807
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.04389377 -0.03866158  0.08163075] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [-0.12113453 -0.52558305  0.05259478] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5401.37520638754
# DEBUG:interpolANI:		incremental_work: -1.223472281708382e-05
# DEBUG:interpolANI:		complex_positions_sample: [-0.04389377 -0.03866158  0.08163075] nm
# DEBUG:interpolANI:		complex_velocities_sample: [-0.12113453 -0.52558305  0.05259478] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5401.375203328859, 772.0976942957618,  -4629.277509033098
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 740.0832889301271
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 740.0832889301271
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1320.3967093003762
# DEBUG:interpolANI:				ke_new: 741.026689757335
# DEBUG:interpolANI:				 heat change: 0.9434008272079382
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 680.9301367071964
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5305.023813454606, 680.9301367071964, -4624.0936767474095
# DEBUG:interpolANI:			acceptance_probability: 0.005606479560840531
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 4.24043145848043
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.04400313 -0.0392262   0.08181308] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [-0.03161741 -0.55833717  0.23951474] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5305.023819571968
# DEBUG:interpolANI:		incremental_work: 6.11736140854191e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.04400313 -0.0392262   0.08181308] nm
# DEBUG:interpolANI:		complex_velocities_sample: [-0.03161741 -0.55833717  0.23951474] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5305.023819571968, 680.9301367071964,  -4624.093682864771
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 637.2550869533468
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 637.2550869533468
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1259.2714738027073
# DEBUG:interpolANI:				ke_new: 639.1294387111143
# DEBUG:interpolANI:				 heat change: 1.8743517577674993
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 592.8242530246632
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5211.290155285817, 592.8242530246632, -4618.465902261153
# DEBUG:interpolANI:			acceptance_probability: 0.0035965486431319632
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 3.7534288458502942
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.04396784 -0.03978142  0.08213956] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.15412935 -0.51011192  0.33480736] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5211.290146109775
# DEBUG:interpolANI:		incremental_work: 0.0
# DEBUG:interpolANI:		complex_positions_sample: [-0.04396784 -0.03978142  0.08213956] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.15412935 -0.51011192  0.33480736] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5211.290155285817, 592.8242530246633,  -4618.465902261153
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 570.4423974122485
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 570.4423974122485
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1345.5635288423039
# DEBUG:interpolANI:				ke_new: 573.4637162361811
# DEBUG:interpolANI:				 heat change: 3.0213188239325746
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 563.0096793054257
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5177.639882072428, 563.0096793054257, -4614.630202767003
# DEBUG:interpolANI:			acceptance_probability: 0.02158623374372268
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 0.814380670217929
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.0436932  -0.04024591  0.08248703] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.42236488 -0.39144509  0.2924404 ] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5177.639879013747
# DEBUG:interpolANI:		incremental_work: -9.176041203318164e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.0436932  -0.04024591  0.08248703] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.42236488 -0.39144509  0.2924404 ] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5177.639888189789, 563.0096793054257,  -4614.630208884364
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 578.249670153996
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 578.249670153996
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1289.546007969286
# DEBUG:interpolANI:				ke_new: 581.9202902793643
# DEBUG:interpolANI:				 heat change: 3.6706201253682593
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 603.8296539374127
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5217.185477884239, 603.8296539374127, -4613.355823946827
# DEBUG:interpolANI:			acceptance_probability: 0.2796028885863005
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: -2.3962351878308255
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.04313996 -0.04055783  0.08269978] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.67962513 -0.22521278  0.09367949] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5217.1854717668775
# DEBUG:interpolANI:		incremental_work: 3.0586797947762534e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.04313996 -0.04055783  0.08269978] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.67962513 -0.22521278  0.09367949] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5217.185468708198, 603.8296539374127,  -4613.355814770785
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 646.6390789766209
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 646.6390789766209
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1319.989556810441
# DEBUG:interpolANI:				ke_new: 647.8107558275399
# DEBUG:interpolANI:				 heat change: 1.1716768509189706
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 677.2145194165677
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5293.350193647401, 677.2145194165677, -4616.1356742308335
# DEBUG:interpolANI:			acceptance_probability: 1.0
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: -3.9515363109670716
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.04230654 -0.04070223  0.08269747] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.95180818 -0.07812093 -0.1013863 ] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5293.350193647401
# DEBUG:interpolANI:		incremental_work: 6.11736140854191e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.04230654 -0.04070223  0.08269747] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.95180818 -0.07812093 -0.1013863 ] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5293.350196706082, 677.2145194165678,  -4616.135677289514
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 719.6216224316121
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 719.6216224316121
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1300.022105895823
# DEBUG:interpolANI:				ke_new: 719.0812856488236
# DEBUG:interpolANI:				 heat change: -0.5403367827884722
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 726.3024583885949
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5345.7716917284515, 726.3024583885949, -4619.469233339856
# DEBUG:interpolANI:			acceptance_probability: 1.0
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: -2.793219267553468
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.04126809 -0.04074172  0.08247243] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 1.06824977 -0.02965501 -0.31465034] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5345.7716917284515
# DEBUG:interpolANI:		incremental_work: -6.117360499047209e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.04126809 -0.04074172  0.08247243] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 1.06824977 -0.02965501 -0.31465034] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5345.771685611091, 726.3024583885949,  -4619.469227222497
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 740.9646406487658
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 740.9646406487658
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1349.206726048088
# DEBUG:interpolANI:				ke_new: 743.1720250711281
# DEBUG:interpolANI:				 heat change: 2.2073844223623382
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 714.8764536839179
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5331.830455441406, 714.8764536839179, -4616.954001757488
# DEBUG:interpolANI:			acceptance_probability: 0.08084468250468331
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 0.3078410426460323
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.04019551 -0.04077659  0.08207382] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 1.0181263  -0.06973016 -0.41973666] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5331.830449324046
# DEBUG:interpolANI:		incremental_work: 9.176042112812866e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.04019551 -0.04077659  0.08207382] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 1.0181263  -0.06973016 -0.41973666] nm/ps
# ...
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.00161658 -0.05118076  0.07532488] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.44693349  0.34420952 -0.46300351] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5328.914901900465
# DEBUG:interpolANI:		incremental_work: -6.117360499047209e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.00161658 -0.05118076  0.07532488] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.44693349  0.34420952 -0.46300351] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5328.914889665743, 784.8011112831532,  -4544.113778382591
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 784.4258134012209
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 784.4258134012209
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1335.7704057833462
# DEBUG:interpolANI:				ke_new: 786.3510358814848
# DEBUG:interpolANI:				 heat change: 1.9252224802638693
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 762.0570478115841
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5303.536589653007, 762.0570478115841, -4541.479541841422
# DEBUG:interpolANI:			acceptance_probability: 0.07177374479590076
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 0.7090140609044511
# DEBUG:interpolANI:		complex_positions_sample updated: [-0.00099668 -0.05071238  0.07478152] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.83841773  0.51453301 -0.60840366] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5303.536586594326
# DEBUG:interpolANI:		incremental_work: 9.176043022307567e-06
# DEBUG:interpolANI:		complex_positions_sample: [-0.00099668 -0.05071238  0.07478152] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.83841773  0.51453301 -0.60840366] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5303.536592711687, 762.0570478115841,  -4541.479544900103
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 753.536104776813
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 753.536104776813
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1314.090152807376
# DEBUG:interpolANI:				ke_new: 756.1048479761448
# DEBUG:interpolANI:				 heat change: 2.568743199331834
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 729.2343740260668
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5267.089060300008, 729.2343740260668, -4537.854686273941
# DEBUG:interpolANI:			acceptance_probability: 0.026652865087855828
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 1.0561154268299333
# DEBUG:interpolANI:		complex_positions_sample updated: [ 8.42028267e-05 -5.01460049e-02  7.40808163e-02] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 1.3165348   0.53688101 -0.76398588] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5267.0890664173685
# DEBUG:interpolANI:		incremental_work: -6.117360499047209e-06
# DEBUG:interpolANI:		complex_positions_sample: [ 8.42028267e-05 -5.01460049e-02  7.40808163e-02] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 1.3165348   0.53688101 -0.76398588] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5267.089060300008, 729.2343740260668,  -4537.854686273941
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 720.2837914622561
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 720.2837914622561
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1316.3475397706238
# DEBUG:interpolANI:				ke_new: 719.4412536845159
# DEBUG:interpolANI:				 heat change: -0.8425377777401764
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 697.677194360379
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5235.659595099735, 697.677194360379, -4537.982400739356
# DEBUG:interpolANI:			acceptance_probability: 1.0
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 0.7148233123251657
# DEBUG:interpolANI:		complex_positions_sample updated: [ 0.00163601 -0.04963296  0.07330979] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 1.72534353  0.41986118 -0.74277333] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5235.659601217096
# DEBUG:interpolANI:		incremental_work: 0.0
# DEBUG:interpolANI:		complex_positions_sample: [ 0.00163601 -0.04963296  0.07330979] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 1.72534353  0.41986118 -0.74277333] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5235.659595099735, 697.6771943603791,  -4537.982400739356
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 695.3575172396941
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 695.3575172396941
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1293.1383458751088
# DEBUG:interpolANI:				ke_new: 695.4932840546154
# DEBUG:interpolANI:				 heat change: 0.13576681492133957
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 682.8746246239514
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5220.664092717055, 682.8746246239514, -4537.789468093103
# DEBUG:interpolANI:			acceptance_probability: 0.8245375079594103
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 0.05716583133187214
# DEBUG:interpolANI:		complex_positions_sample updated: [ 0.00356222 -0.04934459  0.072591  ] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 2.02206259  0.11895394 -0.66425381] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5220.664092717055
# DEBUG:interpolANI:		incremental_work: 6.117360499047209e-06
# DEBUG:interpolANI:		complex_positions_sample: [ 0.00356222 -0.04934459  0.072591  ] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 2.02206259  0.11895394 -0.66425381] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5220.664098834415, 682.8746246239514,  -4537.789474210464
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 689.7998349132
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 689.7998349132
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1344.9058026289085
# DEBUG:interpolANI:				ke_new: 693.2321079693228
# DEBUG:interpolANI:				 heat change: 3.4322730561227672
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 688.234133068226
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5223.246736211687, 688.234133068226, -4535.012603143461
# DEBUG:interpolANI:			acceptance_probability: 0.062232925712562434
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: -0.6554019891202643
# DEBUG:interpolANI:		complex_positions_sample updated: [ 0.00565559 -0.0494021   0.07198341] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 2.04202266 -0.22830079 -0.53488434] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5223.246733153006
# DEBUG:interpolANI:		incremental_work: 6.11736140854191e-06
# DEBUG:interpolANI:		complex_positions_sample: [ 0.00565559 -0.0494021   0.07198341] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 2.04202266 -0.22830079 -0.53488434] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5223.246733153006, 688.234133068226,  -4535.01260008478
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 701.602976978597
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 701.602976978597
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1355.6191104053612
# DEBUG:interpolANI:				ke_new: 701.03561219605
# DEBUG:interpolANI:				 heat change: -0.5673647825469743
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 698.2020365164502
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5234.485188965163, 698.2020365164502, -4536.283152448713
# DEBUG:interpolANI:			acceptance_probability: 1.0
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: -0.703187581385464
# DEBUG:interpolANI:		complex_positions_sample updated: [ 0.00761112 -0.04978801  0.07152495] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 1.76093833 -0.4965827  -0.38810178] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5234.485195082525
# DEBUG:interpolANI:		incremental_work: 3.0586797947762534e-06
# DEBUG:interpolANI:		complex_positions_sample: [ 0.00761112 -0.04978801  0.07152495] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 1.76093833 -0.4965827  -0.38810178] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5234.485192023844, 698.2020365164502,  -4536.283155507394
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 712.3334545138099
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 712.3334545138099
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1337.43621692136
# DEBUG:interpolANI:				ke_new: 712.5095378379514
# DEBUG:interpolANI:				 heat change: 0.17608332414147299
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 707.3420948106138
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5243.6063731672675, 707.3420948106138, -4536.264278356653
# DEBUG:interpolANI:			acceptance_probability: 0.9812999068046658
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: -0.15720617340048193
# DEBUG:interpolANI:		complex_positions_sample updated: [ 0.00922188 -0.05035913  0.07120846] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 1.38749714 -0.57201412 -0.27189928] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5243.60638846067
# DEBUG:interpolANI:		incremental_work: -3.0586797947762534e-06
# DEBUG:interpolANI:		complex_positions_sample: [ 0.00922188 -0.05035913  0.07120846] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 1.38749714 -0.57201412 -0.27189928] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5243.606379284628, 707.3420948106138,  -4536.264284474014
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 718.6648910003861
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 718.6648910003861
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1296.5122251561688
# DEBUG:interpolANI:				ke_new: 718.9026806001343
# DEBUG:interpolANI:				 heat change: 0.23778959974822556
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 711.5471658169952
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5247.168146743336, 711.5471658169952, -4535.620980926341
# DEBUG:interpolANI:			acceptance_probability: 0.5255533625005673
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 0.40551394792476003
# DEBUG:interpolANI:		complex_positions_sample updated: [ 0.01037096 -0.05094052  0.07101409] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.88623537 -0.51147341 -0.16222039] nm/ps
# DEBUG:interpolANI:	lambda value: 0.0
# DEBUG:interpolANI:		new reduced potential: -5247.168140625975
# DEBUG:interpolANI:		incremental_work: 0.0
# DEBUG:interpolANI:		complex_positions_sample: [ 0.01037096 -0.05094052  0.07101409] nm
# DEBUG:interpolANI:		complex_velocities_sample: [ 0.88623537 -0.51147341 -0.16222039] nm/ps
# DEBUG:interpolANI:		propagating particle 1 steps...
# DEBUG:interpolANI:			before propagation u, ke, E_tot: -5247.168146743336, 711.5471658169952,  -4535.620980926341
# DEBUG:interpolANI:			a, b scales: 0.999000499833375, 0.044699008184376096
# DEBUG:interpolANI:			beginning integration...
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 721.4543971271934
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				O
# DEBUG:interpolANI:				ke_old: 721.4543971271934
# DEBUG:interpolANI:				maxwell boltzmann sample KE: 1291.9791803271264
# DEBUG:interpolANI:				ke_new: 724.6632562228781
# DEBUG:interpolANI:				 heat change: 3.2088590956847156
# DEBUG:interpolANI:				R
# DEBUG:interpolANI:				V
# DEBUG:interpolANI:					updated ke: 719.0683350227544
# DEBUG:interpolANI:			after propagation u, ke, E_new: -5250.897847497664, 719.0683350227544, -4531.829512474909
# DEBUG:interpolANI:			acceptance_probability: 0.022562445657321996
# DEBUG:interpolANI:			accepted
# DEBUG:interpolANI:		shadow_work: 0.5826093557469676
# DEBUG:interpolANI:		complex_positions_sample updated: [ 0.01098146 -0.05140096  0.07081106] nm
# DEBUG:interpolANI:		complex_velocities_sample updated: [ 0.36683586 -0.34470118 -0.29321205] nm/ps
# DEBUG:interpolANI:incremental works: [0.0, 0.0, -1.0705382010200992e-05, -1.5293408068828285e-06, -4.588020601659082e-06, -9.176041203318164e-06, 7.646701305930037e-06, 1.223472281708382e-05, 3.058680704270955e-06, -1.2234721907589119e-05, 0.0, 0.0, -3.058680704270955e-06, 6.11736140854191e-06, 9.176042112812866e-06, 3.058680704270955e-06, 0.0, -6.11736140854191e-06, -6.117360499047209e-06, -3.0586797947762534e-06, -6.117360499047209e-06, 0.0, -1.2234721907589119e-05, 6.117360499047209e-06, -3.058680704270955e-06, -1.223472281708382e-05, 6.11736140854191e-06, 0.0, -9.176041203318164e-06, 3.0586797947762534e-06, 6.11736140854191e-06, -6.117360499047209e-06, 9.176042112812866e-06, -6.11736140854191e-06, -3.058681613765657e-06, -3.058680704270955e-06, -6.117360499047209e-06, -9.176043022307567e-06, 9.176041203318164e-06, 9.176041203318164e-06, -1.2234721907589119e-05, -6.11736140854191e-06, -6.117362318036612e-06, -3.058681613765657e-06, -6.11736140854191e-06, 6.117359589552507e-06, 3.058681613765657e-06, 1.2234721907589119e-05, 6.11736140854191e-06, -3.058680704270955e-06, -6.117360499047209e-06, 3.0586797947762534e-06, 6.11736140854191e-06, -9.176043022307567e-06, -3.058681613765657e-06, -6.11736140854191e-06, 0.0, 6.117360499047209e-06, 9.176042112812866e-06, 0.0, 6.11736140854191e-06, 0.0, 0.0, -9.176042112812866e-06, -1.835208422562573e-05, 3.0586797947762534e-06, -6.11736140854191e-06, 1.2234721907589119e-05, 3.058680704270955e-06, 3.058680704270955e-06, -9.176041203318164e-06, 3.058680704270955e-06, -3.058680704270955e-06, 0.0, 3.058680704270955e-06, 3.058681613765657e-06, -3.058680704270955e-06, -3.058680704270955e-06, -6.117360499047209e-06, -3.0586797947762534e-06, -3.0586797947762534e-06, 6.117360499047209e-06, 3.058680704270955e-06, 3.058680704270955e-06, -3.0586797947762534e-06, 3.058680704270955e-06, 0.0, 3.058680704270955e-06, 6.11736140854191e-06, -6.117360499047209e-06, -3.058680704270955e-06, -6.117360499047209e-06, 9.176043022307567e-06, -6.117360499047209e-06, 0.0, 6.117360499047209e-06, 6.11736140854191e-06, 3.0586797947762534e-06, -3.0586797947762534e-06, 0.0]
